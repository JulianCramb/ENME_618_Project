# %%
import laspy
import numpy as np
from utilities import load_lidar, visualize, simulate_noise, print_lidar

# %% [markdown]
# # Noise Simulation for Urban LiDAR

# %%
#pc1 = 'Data/segmented_points_urban.las'
pc1 = 'Data/300-5050_2015.las'

xyz, intensity, classification, scan_angle, header = load_lidar(pc1)

print(xyz.shape)
# Out:
# (15659171, 3)

# %%
visualize(xyz, classification)
# Out:
# 2025-11-22 12:06:48.121 (   5.712s) [    7F5F1D4FF440]vtkXOpenGLRenderWindow.:1458  WARN| bad X server connection. DISPLAY=
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:06:48.137 (   5.729s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x26a2cd90): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:06:48.174 (   5.766s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x26a5cfe0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# /home/mabel/.conda/envs/lidar/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:06:48.459 (   6.050s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x26d21e30): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
xyz_noisy, classification_noisy, intensity_noisy = simulate_noise(
    xyz,
    intensity=intensity,
    classification=classification,
    scan_angle=None,
    num_per_type=10000,
    num_outliers = 50000,
    apply={
        "range": True,
        "horizontal": True,
        "scan_angle": True,
        "surface": True,
        "outliers": True,
        "intensity": True,
    }
)

print(xyz_noisy.shape)
# Out:
# (15709171, 3)

# %%
visualize(xyz_noisy, classification_noisy)
# Out:
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:07:15.522 (  33.113s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x2a6ea2e0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:07:15.527 (  33.118s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x3db2a820): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# /home/mabel/.conda/envs/lidar/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:07:15.760 (  33.352s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x2a6ea2e0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
print_lidar(xyz_noisy, intensity_noisy, classification_noisy, 'Data/300-5050_2015_w_Noise.las', header)
# Out:
# Successfully saved LAS file to: Data/300-5050_2015_w_Noise.las

# %% [markdown]
# # Noise Simulation for Forest LiDAR

# %%
#pc1 = 'Data/segmented_points_forest.las'
pc1 = 'Data/303-5059_2015.las'

xyz, intensity, classification, scan_angle, header = load_lidar(pc1)

print(xyz.shape)
# Out:
# (18066876, 3)

# %%
visualize(xyz, classification)
# Out:
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:07:43.422 (  61.013s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x3e752550): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:07:43.427 (  61.018s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x3e752550): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# /home/mabel/.conda/envs/lidar/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:07:43.645 (  61.236s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x139eb9c60): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
xyz_noisy, classification_noisy, intensity_noisy = simulate_noise(
    xyz,
    intensity=intensity,
    classification=classification,
    scan_angle=None,
    num_per_type=10000,
    num_outliers = 50000,
    apply={
        "range": True,
        "horizontal": True,
        "scan_angle": True,
        "surface": True,
        "outliers": True,
        "intensity": True,
    }
)

print(xyz_noisy.shape)
# Out:
# (18116876, 3)

# %%
visualize(xyz_noisy, classification_noisy)
# Out:
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:08:20.837 (  98.428s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x3e752550): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:08:20.842 (  98.433s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x3e752550): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# /home/mabel/.conda/envs/lidar/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card2: Permission denied
#
# 2025-11-22 12:08:21.092 (  98.683s) [    7F5F1D4FF440] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x3e746140): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
print_lidar(xyz_noisy, intensity_noisy, classification_noisy, 'Data/303-5059_2015_w_Noise.las', header)
# Out:
# Successfully saved LAS file to: Data/303-5059_2015_w_Noise.las
